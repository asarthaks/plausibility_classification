# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# ExploratoryDataAnalysis.ipynb  gpu_test.ipynb

# %% [markdown]
# ## [ADEPT]
#
#
# ## DATASET DESCRIPTION ##
#
# The ADEPT release comprises of three .json files (split according to train, valiation and test sets used for our experimentations) with 6 keys per instance.
#
# "sentence1" provides the sentence without the adjectival modifier added.
#
# "sentence2" provides the sentence with the adjectival modifier added.
#
# "modifier" provides specifically the ajectival modifier.
#
# "noun" provides the noun in the sentence to which the adjectival modifier attaches.
#
# "label" provides the annotated label ranging from 0-5 representing respectively, the plausibility change corresponing to the increasing range from impossible to necessarily true.
#
# "idx" is the specific sentence identifier number.

# %%
# !ls ../datasets/adept/train-dev-test-split/
# Out:
# README.md  test.json  train.json  val.json

# %%
import json

# %%
adept_data_path = "../datasets/adept/train-dev-test-split"
split = "train"

# %%
train_data = json.load(open('{}/{}.json'.format(adept_data_path, split), 'r'))

# %%
df_train = pd.DataFrame(train_data)
df_train.head()
# Out:
#                                  sentence1  \
# 0  The effect of sleeping is rejuvenation.
# 1        A toothbrush is for fresh breath.
# 2                      A scene is painted.
# 3                   A bone breaks a tooth.
# 4               A trip causes a happening.
#
#                                            sentence2    modifier        noun  \
# 0  The effect of additional sleeping is rejuvenat...  additional    sleeping
# 1          A regular toothbrush is for fresh breath.     regular  toothbrush
# 2                       A negative scene is painted.    negative       scene
# 3                    An alleged bone breaks a tooth.     alleged        bone
# 4                A fabulous trip causes a happening.    fabulous        trip
#
#    label    idx
# 0      3  13484
# 1      2   2620
# 2      2   3324
# 3      2  10610
# 4      2  14917

# %% [markdown]
# #  Meta Level

# %%
df_train.label.describe()
# Out:
# count    12892.000000
# mean         1.692057
# std          0.812853
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000
# Name: label, dtype: float64

# %%
df_train.label.value_counts()
# Out:
# label
# 2    8633
# 0    1762
# 1    1504
# 3     928
# 4      65
# Name: count, dtype: int64

# %%
label_to_class_map = {0:"impossible", 1:"less likely", 2:"equally likely", 3:"more likely", 4:"necessarily true"}

# %%
df_train.label.apply(lambda x: label_to_class_map[x]).value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='label'>

# %%
df_train.shape
# Out:
# (12892, 6)

# %% [markdown]
# Labels are as follows:
#
# 0->4 in  increasing order of plausiablity
#
# From impossible to necessarily true

# %% [markdown]
# ## Characterstic 1
#
# #### Here, we can see that the train dataset is imbalanced, there are only 65 data points which falls under the category 5 (label 4) which corrosponds to the label: "necessarily true". Similiarly, we can see that there are less data points for "more likely" event.
#
# #### To tackle this, in our evaluation metrics, we have to make sure that recall for category 5 is high, so that we know that our model is not biased and classifying all the data points as implausible.
#
# #### Another thing we can do is, we can try to augment the dataset and make more datapoints for the category 5. We'll try that in a later section of this analysis.

# %% [markdown]
# Let's look at other characterstics first

# %%
for idx, row in df_train.iterrows():
    if "monkey" in row.to_dict()['sentence1']:
        print(row)
# Out:
# sentence1        A monkey is hanging off a tree.
# sentence2    A fly monkey is hanging off a tree.
# modifier                                     fly
# noun                                      monkey
# label                                          0
# idx                                        12228
# Name: 2398, dtype: object
# sentence1        A monkey has a nose.
# sentence2    A new monkey has a nose.
# modifier                          new
# noun                           monkey
# label                               2
# idx                             12265
# Name: 2778, dtype: object
# sentence1          A monkey wants a banana.
# sentence2    A giant monkey wants a banana.
# modifier                              giant
# noun                                 monkey
# label                                     2
# idx                                    2239
# Name: 9290, dtype: object
# sentence1         A monkey turns on a light switch.
# sentence2    A dead monkey turns on a light switch.
# modifier                                       dead
# noun                                         monkey
# label                                             0
# idx                                            3416
# Name: 10646, dtype: object
# sentence1          A monkey attempts to climb a tree.
# sentence2    A sweet monkey attempts to climb a tree.
# modifier                                        sweet
# noun                                           monkey
# label                                               2
# idx                                              3119
# Name: 12166, dtype: object
# sentence1         A monkey moves from one tree to another.
# sentence2    A dead monkey moves from one tree to another.
# modifier                                              dead
# noun                                                monkey
# label                                                    0
# idx                                                  11521
# Name: 12776, dtype: object

# %% [markdown]
# #### Here, from the result 1 and result 5, we can see that the label represents the likelihood of the sentence 2 (with the modifier before noun)

# %% [markdown]
# # Text Statistics

# %% [markdown]
# #### Word Count
# #### Let's take the word count of sentence 2 into consideration (word count of sentence 1 will always be 1 less)

# %%
total_word_count = 0
word_freq_map = dict()
for idx, row in df_train.iterrows():
    text = row.to_dict()['sentence2']
    words = text.split()
    total_word_count += len(words)
    for word in words:
        word_freq_map[word] = word_freq_map.get(word, 0) + 1

# %%
word_freq_map
# Out:
# {'The': 451,
#  'effect': 150,
#  'of': 917,
#  'additional': 10,
#  'sleeping': 30,
#  'is': 6819,
#  'rejuvenation.': 1,
#  'A': 6116,
#  'regular': 19,
#  'toothbrush': 9,
#  'for': 4431,
#  'fresh': 14,
#  'breath.': 11,
#  'negative': 6,
#  'scene': 4,
#  'painted.': 5,
#  'An': 1352,
#  'alleged': 44,
#  'bone': 21,
#  'breaks': 9,
#  'a': 4297,
#  'tooth.': 3,
#  'fabulous': 6,
#  'trip': 5,
#  'causes': 246,
#  'happening.': 1,
#  'Something': 124,
#  'that': 173,
#  'might': 120,
#  'happen': 122,
#  'as': 161,
#  'consequence': 120,
#  'evocative': 1,
#  'singing': 24,
#  'you': 122,
#  'look': 14,
#  'funny.': 4,
#  'Healing': 1,
#  'rain': 14,
#  'makes': 37,
#  'wet.': 7,
#  'Mindful': 3,
#  'breathing': 7,
#  'respiration.': 3,
#  'You': 1557,
#  'use': 1569,
#  'an': 628,
#  'overlooked': 1,
#  'rule': 13,
#  'to': 2658,
#  'guide': 4,
#  'you.': 35,
#  'main': 46,
#  'ranch': 11,
#  'found': 156,
#  'in': 614,
#  'australia.': 3,
#  'outstanding': 5,
#  'year': 7,
#  'made': 222,
#  'up': 125,
#  '365': 2,
#  'days.': 11,
#  'erroneous': 8,
#  'story': 22,
#  'has': 340,
#  'sentence.': 6,
#  'Natural': 11,
#  'art': 27,
#  'enjoyment.': 7,
#  'Faulty': 4,
#  'one': 112,
#  'relaxes': 2,
#  'beside': 1,
#  'lake.': 7,
#  'Sometimes': 145,
#  'former': 309,
#  'work': 24,
#  'exhaustion.': 1,
#  'local': 42,
#  'photographer': 3,
#  'positions': 13,
#  'the': 939,
#  'model.': 5,
#  'Historic': 30,
#  'people': 111,
#  'works': 6,
#  'teams.': 4,
#  'virtual': 324,
#  'album': 17,
#  'reproduce': 1,
#  'music.': 74,
#  'Fallen': 1,
#  'mankind': 4,
#  'humanity.': 1,
#  'hot': 30,
#  'home': 20,
#  'family.': 14,
#  'foreign': 11,
#  'lobby': 7,
#  'have': 68,
#  'drink.': 18,
#  'That': 7,
#  'false': 106,
#  'rumor': 1,
#  'spreads': 11,
#  'and': 227,
#  'spread.': 1,
#  'rear': 16,
#  'carpet': 9,
#  'used': 1689,
#  'saving': 11,
#  'floor.': 23,
#  'good': 109,
#  'bottle': 14,
#  'pouring': 3,
#  'liquid': 20,
#  'from.': 15,
#  'internal': 16,
#  'crane': 7,
#  'lifts': 9,
#  'heavy': 27,
#  'weight.': 9,
#  'potential': 117,
#  'stage': 12,
#  'putting': 26,
#  'on': 298,
#  'shows.': 3,
#  'Everyday': 2,
#  'cycling': 2,
#  'more': 45,
#  'efficient': 2,
#  'than': 48,
#  'driving.': 3,
#  'substantial': 5,
#  'platform': 5,
#  'drilling': 1,
#  'oil': 14,
#  'ocean.': 10,
#  'artificial': 137,
#  'cup': 9,
#  'hold': 62,
#  'coffee.': 11,
#  'old': 80,
#  'library': 11,
#  'organizing': 7,
#  'knowlege.': 3,
#  'Virtuoso': 1,
#  'dancing': 10,
#  'fun.': 27,
#  'single': 42,
#  'bell': 9,
#  'calling.': 2,
#  'temple': 11,
#  'religious': 11,
#  'ceremonies.': 1,
#  'suburban': 6,
#  'mom': 13,
#  'mothers': 8,
#  'child.': 25,
#  'electronic': 22,
#  'candle': 16,
#  'lights': 14,
#  'room.': 37,
#  'lousy': 2,
#  'psychiatrist': 8,
#  'listens': 16,
#  'neurotic': 2,
#  "person's": 9,
#  'fears.': 2,
#  'phantom': 1,
#  'pain': 11,
#  'hurt.': 2,
#  'athlete': 13,
#  'runs': 12,
#  'fast.': 9,
#  'venous': 1,
#  'disease': 18,
#  'making': 147,
#  'sick.': 5,
#  'happy': 13,
#  'tourist': 12,
#  'travels': 10,
#  'countries.': 7,
#  'attributable': 1,
#  'fortune': 6,
#  'stop': 10,
#  'working': 17,
#  'living.': 9,
#  'Some': 67,
#  'dead': 240,
#  'tennis': 6,
#  'played': 27,
#  'red': 37,
#  'clay.': 4,
#  'So-called': 15,
#  'wind': 11,
#  'separates': 18,
#  'chaff': 1,
#  'from': 243,
#  'wheat': 12,
#  'seeds.': 6,
#  'physical': 11,
#  'sun': 25,
#  'gases.': 4,
#  'imaginary': 26,
#  'ball': 13,
#  'with.': 27,
#  'financial': 9,
#  'expert': 9,
#  'teaches': 7,
#  'what': 17,
#  'they': 3,
#  'know.': 3,
#  'fictional': 37,
#  'surgeon': 4,
#  'holds': 28,
#  'scalpal.': 1,
#  'likely': 53,
#  'place': 40,
#  'event.': 13,
#  'Solid': 7,
#  'china': 7,
#  'lot': 13,
#  'people.': 118,
#  'absolute': 3,
#  'clown': 15,
#  'acts': 11,
#  'silly.': 2,
#  'westbound': 3,
#  'freeway': 11,
#  'similar': 30,
#  'highway.': 3,
#  'Proposed': 10,
#  'shrink': 1,
#  'shrink.': 1,
#  'Transparent': 4,
#  'metal': 24,
#  'sometimes': 12,
#  'burns.': 5,
#  'mouse': 8,
#  'eats': 15,
#  'grain.': 3,
#  'Our': 3,
#  'supportive': 3,
#  'family': 26,
#  'visits': 16,
#  'zoo.': 5,
#  'exclusive': 9,
#  'tent': 4,
#  'pitched': 4,
#  'campground.': 1,
#  'Likely': 30,
#  'stupidity': 1,
#  'contangeous.': 1,
#  'Fake': 69,
#  'sport': 8,
#  'by': 141,
#  'humans.': 13,
#  'pretty': 13,
#  'penny': 10,
#  'cheap': 9,
#  'hookers.': 1,
#  'full': 37,
#  'housekeeper': 2,
#  'cleans': 13,
#  'rooms': 3,
#  'house.': 64,
#  'presumed': 10,
#  'consumer': 3,
#  'pays': 11,
#  'purchase.': 3,
#  'new': 169,
#  'purse': 16,
#  'carrying': 36,
#  'money.': 77,
#  'Good': 27,
#  'compost': 1,
#  'smells': 11,
#  'bad.': 18,
#  'future': 121,
#  'science': 22,
#  'learn': 12,
#  'about': 45,
#  'nearly': 1,
#  'anything.': 12,
#  'portable': 12,
#  'hoist': 4,
#  'moving': 28,
#  'objects.': 28,
#  'problem': 2,
#  'slows': 14,
#  'work.': 37,
#  'sensory': 3,
#  'pit': 5,
#  'trapping': 2,
#  'animal.': 12,
#  'decorative': 20,
#  'grill': 13,
#  'cooking': 20,
#  'over': 26,
#  'fire.': 26,
#  'showroom': 13,
#  'displaying': 28,
#  'fabric.': 9,
#  'Pathological': 3,
#  'cleaning': 38,
#  'removing': 13,
#  'food': 62,
#  'dishes.': 9,
#  'brightly': 1,
#  'rooster': 3,
#  'pet.': 17,
#  '6th': 5,
#  'supermarket': 9,
#  'buy': 15,
#  'raisins.': 1,
#  'wireless': 6,
#  'entry.': 3,
#  'Green': 14,
#  'paint': 18,
#  'put': 23,
#  'bucket.': 1,
#  'individual': 15,
#  'shield': 2,
#  'protect.': 1,
#  'abstracted': 1,
#  'dog': 28,
#  'mouth.': 10,
#  'live': 35,
#  'miner': 6,
#  'mines': 10,
#  'earth.': 12,
#  'north': 10,
#  'van': 10,
#  'seats': 13,
#  'inside.': 5,
#  'oath': 2,
#  'vow.': 1,
#  'Potential': 33,
#  'cancer': 4,
#  'kills.': 1,
#  'primary': 39,
#  'judge': 7,
#  'considers': 5,
#  'mitigating': 1,
#  'evidence.': 6,
#  'strong': 17,
#  'opponent': 4,
#  'deals': 6,
#  'blow.': 5,
#  'controversial': 4,
#  'comedian': 6,
#  'wants': 75,
#  'make': 127,
#  'laugh.': 2,
#  'incorporated': 2,
#  'projector': 1,
#  'show': 32,
#  'presentations.': 3,
#  'top': 34,
#  'contestant': 4,
#  'answering': 2,
#  'question.': 10,
#  'classic': 19,
#  'orchestra': 3,
#  'composed': 12,
#  'musicians.': 2,
#  'Prepared': 2,
#  'marijuana': 6,
#  'contains': 78,
#  'thc.': 1,
#  'student': 18,
#  'finishing': 4,
#  'her': 36,
#  'degree.': 5,
#  'dirty': 11,
#  'floor': 17,
#  'man-made.': 1,
#  'carbonaceous': 3,
#  'meteorite': 1,
#  'may': 55,
#  'hit': 8,
#  'shark': 6,
#  'head.': 11,
#  'fabricated': 20,
#  'carries': 17,
#  'load.': 2,
#  'long': 43,
#  'stick': 16,
#  'building': 38,
#  'Big': 7,
#  'mike': 4,
#  'fixes': 15,
#  'his': 102,
#  'car.': 38,
#  'Clean': 6,
#  'eating': 38,
#  'experiencing': 1,
#  'delicious': 3,
#  'tastes.': 1,
#  'Wobbly': 1,
#  'bob': 10,
#  'attempts': 12,
#  'swim.': 4,
#  'true': 24,
#  'ruler': 10,
#  'means': 23,
#  'measuring': 13,
#  'tool.': 5,
#  'train': 14,
#  'transports': 7,
#  'mail.': 11,
#  'third': 27,
#  'bucket': 10,
#  'water.': 114,
#  'dummy': 3,
#  'pill': 11,
#  'headache.': 5,
#  'unknown': 3,
#  'architect': 4,
#  'walls': 8,
#  'plumbing': 10,
#  'with': 201,
#  'exactness.': 1,
#  'synthetic': 4,
#  'handbag': 15,
#  'carry': 38,
#  'makeup.': 4,
#  'ministerial': 1,
#  'experiences': 5,
#  'acute': 1,
#  'embarassment.': 1,
#  'fake': 142,
#  'cop': 2,
#  'fines': 7,
#  'person.': 52,
#  'great': 59,
#  'bass': 5,
#  'create': 17,
#  'fish': 23,
#  'dinner.': 15,
#  'controller': 1,
#  'controls': 8,
#  'device.': 3,
#  'puzzle': 25,
#  'fools': 9,
#  'genuinely': 2,
#  'clip': 15,
#  'some': 34,
#  'hairstyles.': 1,
#  'teeth.': 21,
#  'Thin': 6,
#  'bananas': 3,
#  'are': 106,
#  'curved.': 2,
#  'possible': 97,
#  'resin': 7,
#  'binding': 5,
#  'fibers': 1,
#  'together.': 38,
#  'Cellular': 2,
#  'traffic': 7,
#  'down.': 42,
#  'mutual': 3,
#  'predator': 4,
#  'spots': 13,
#  'prey.': 8,
#  'plausible': 6,
#  'argument': 4,
#  'results': 14,
#  'bad': 36,
#  'feelings.': 4,
#  'middle': 4,
#  'tooth': 28,
#  'obtaining': 4,
#  'money': 22,
#  'fairy.': 2,
#  'separate': 19,
#  'pantry': 8,
#  'storing': 58,
#  'food.': 96,
#  'educated': 1,
#  'author': 12,
#  'completes': 7,
#  'book.': 28,
#  'Original': 6,
#  'humor': 1,
#  'lightens': 1,
#  'mood.': 4,
#  'worth': 7,
#  'celebrating': 19,
#  'party.': 10,
#  'haughty': 2,
#  'friend': 22,
#  'borrows': 10,
#  'eggs.': 12,
#  'asymmetric': 1,
#  'route': 5,
#  'driving': 20,
#  'destination.': 4,
#  'huge': 17,
#  'barn': 12,
#  'store': 76,
#  'your': 331,
#  'horses.': 8,
#  'cozy': 6,
#  'pouch': 11,
#  'pocket.': 3,
#  'Laden': 1,
#  'mud': 12,
#  'cakes': 14,
#  'Ideal': 2,
#  'toothpaste': 9,
#  'placed': 8,
#  'toothbrush.': 4,
#  'salmon': 3,
#  'heads': 18,
#  'upstream.': 2,
#  'gorgeous': 3,
#  'fireplace': 11,
#  'decorating': 6,
#  'incredible': 4,
#  'advances': 12,
#  'space': 33,
#  'travel.': 16,
#  'improved': 7,
#  'mill': 8,
#  'grinding': 3,
#  'diversion': 1,
#  'attracting': 4,
#  "someone's": 5,
#  'attention.': 17,
#  'valley': 11,
#  'separating': 9,
#  'moutains.': 1,
#  'historic': 149,
#  'bed': 10,
#  'provides': 5,
#  'comfort.': 11,
#  'modular': 10,
#  'coil': 6,
#  'counter': 14,
#  'conception.': 3,
#  'responsible': 7,
#  'president': 20,
#  'lists': 8,
#  'cabinet': 2,
#  'members.': 5,
#  'mock': 43,
#  'theater': 7,
#  'watching': 11,
#  'movie': 25,
#  'in.': 131,
#  'digital': 19,
#  'world': 9,
#  'beautiful.': 8,
#  'pendant': 4,
#  'continues': 12,
#  'shining.': 1,
#  'body': 44,
#  'if': 13,
#  "it's": 11,
#  'enough.': 1,
#  'open': 36,
#  'bookcase': 10,
#  'books.': 29,
#  'spinal': 1,
#  'band': 5,
#  'includes': 20,
#  'drummer.': 1,
#  'fictitious': 21,
#  'do': 21,
#  'just': 7,
#  'spurious': 10,
#  'talking': 16,
#  'be': 52,
#  'insulted.': 1,
#  'elephant': 8,
#  'tusks.': 1,
#  'proposed': 51,
#  'illustration': 2,
#  'drives': 19,
#  'point.': 12,
#  'green': 33,
#  'couch': 12,
#  'living': 38,
#  'Smart': 3,
#  'jack': 6,
#  'clogged': 5,
#  'ear': 26,
#  'becomes': 16,
#  'infected.': 2,
#  'Indigenous': 2,
#  'chicken': 13,
#  'stirfried': 1,
#  'butter.': 3,
#  'wealthy': 4,
#  'widow': 2,
#  'crying': 2,
#  'husband.': 2,
#  'second': 72,
#  'kettle': 18,
#  'heating': 6,
#  'Theoretical': 14,
#  'change': 6,
#  'constant.': 1,
#  'slow': 10,
#  'glass': 23,
#  'drink': 16,
#  'margaritas': 1,
#  'out': 72,
#  'of.': 17,
#  'storm': 8,
#  'flooding.': 1,
#  'iron': 12,
#  'press': 3,
#  'wrinkles': 1,
#  'cloth.': 6,
#  'lawyer': 11,
#  'proves': 12,
#  'judge.': 2,
#  'cold': 22,
#  'knife': 13,
#  'cutting': 7,
#  'complete': 14,
#  'satchel': 8,
#  'protecting': 27,
#  'things': 85,
#  'weather.': 9,
#  'lawn': 11,
#  'playing': 60,
#  'bowls': 1,
#  'on.': 99,
#  'string': 24,
#  'tie': 3,
#  'knot.': 3,
#  'Universal': 1,
#  'weather': 10,
#  'ice': 15,
#  'form.': 3,
#  'chapel': 12,
#  'services.': 5,
#  'registered': 2,
#  'geologist': 1,
#  'formation': 1,
#  'dip': 1,
#  'information.': 30,
#  'elderly': 3,
#  'lecher': 2,
#  'eyes': 8,
#  'girl.': 3,
#  'unusable': 1,
#  'cafe': 9,
#  'meeting': 23,
#  'someone.': 26,
#  'astronomy.': 2,
#  'upper-level': 1,
#  'line': 19,
#  'indicate': 3,
#  'change.': 8,
#  'engaging': 2,
#  'actress': 7,
#  'stars': 12,
#  'movie.': 17,
#  'fiery': 1,
#  'sword': 11,
#  'intimidating.': 1,
#  'Free': 17,
#  'corn': 15,
#  'creamed': 1,
#  'corn.': 6,
#  'Positive': 8,
#  'time': 29,
#  'doing': 17,
#  'enjoyable': 1,
#  'things.': 127,
#  'villainous': 2,
#  'uncle': 6,
#  'get': 64,
#  'excellent': 13,
#  'chat.': 1,
#  'permanent': 6,
#  'binder': 10,
#  'Old': 12,
#  'waiter': 10,
#  'serves': 10,
#  'litigant': 1,
#  'angry.': 5,
#  'pacifier': 1,
#  'quiets': 13,
#  'baby.': 8,
#  'comb': 27,
#  'remove': 9,
#  'tangles': 4,
#  'hair.': 56,
#  'Your': 25,
#  'legislative': 4,
#  'independence': 2,
#  'precious.': 2,
#  'roommates.': 1,
#  'outdoor': 16,
#  'farmer': 11,
#  'farms': 5,
#  'farms.': 2,
#  'privy': 1,
#  'holding': 115,
#  'cash.': 4,
#  '37th': 1,
#  'congress': 4,
#  'forces': 10,
#  'narrow': 10,
#  'doorway': 17,
#  'enter': 9,
#  'somewhere.': 4,
#  'favorite': 22,
#  'shop': 16,
#  'northern': 10,
#  'passage': 18,
#  'quick': 4,
#  'exits': 1,
#  'entrances.': 1,
#  'award-winning': 4,
#  'entertain': 7,
#  'personal': 42,
#  'altar': 11,
#  'married': 8,
#  'at.': 12,
#  'Much': 18,
#  'patriotism': 2,
#  'both': 6,
#  'creative': 3,
#  'destructive.': 4,
#  'Inexpensive': 1,
#  'cooked': 9,
#  'grill.': 2,
#  'Modular': 2,
#  'cable': 5,
#  'connect.': 4,
#  'homing': 1,
#  'scar': 1,
#  'appears': 16,
#  'fade': 2,
#  'time.': 50,
#  'high-speed': 2,
#  'drill': 8,
#  'hole': 13,
#  'wall.': 21,
#  'Popular': 7,
#  'everything': 9,
#  'its': 36,
#  'own': 8,
#  'special': 31,
#  'purpose.': 10,
#  'knight': 9,
#  'kill': 14,
#  'dragon.': 1,
#  'refrigerated': 1,
#  'minibar': 7,
#  'beautiful': 43,
#  'trombone': 7,
#  'myocardial': 1,
#  'patient': 15,
#  'doctor.': 5,
#  'Future': 46,
#  'sickness': 4,
#  'person': 38,
#  'hoarse.': 1,
#  'mantra': 2,
#  'mind.': 18,
#  'small': 83,
#  'condominium': 9,
#  'alternative': 5,
#  'buying': 28,
#  'stray': 1,
#  'bullet': 12,
#  'murdering.': 1,
#  'systematic': 1,
#  'study': 20,
#  'read': 3,
#  'peace': 1,
#  'quiet.': 2,
#  'swimming': 12,
#  'swallowing': 1,
#  'net': 6,
#  'bridge': 19,
#  'area.': 12,
#  'luxurious': 4,
#  'den': 11,
#  'studying.': 5,
#  'giant': 15,
#  'lizard': 3,
#  'suns': 6,
#  'rock.': 7,
#  'loose': 12,
#  'cannon': 14,
#  'military.': 2,
#  'hormonal': 3,
#  'contraceptive': 8,
#  'avoid': 6,
#  'pregnancy.': 9,
#  'hedge': 1,
#  'fences': 11,
#  'Prophetic': 1,
#  'energy': 6,
#  'gained': 5,
#  'quickly': 2,
#  'carbohydrates.': 4,
#  'happiness.': 5,
#  'original': 35,
#  'mall': 11,
#  'meet': 7,
#  'boreal': 1,
#  'toad': 2,
#  'fly.': 8,
#  'writer': 11,
#  'balls': 1,
#  'discarded': 4,
#  'manuscripts.': 1,
#  'Residential': 3,
#  'trash': 25,
#  'collected': 6,
#  'by.': 4,
#  'hypothetical': 36,
#  'cross': 11,
#  'moat.': 1,
#  'literature': 12,
#  'illustrate.': 1,
#  'being': 39,
#  'dancer': 7,
#  'cuts': 13,
#  'rug.': 1,
#  'thorough': 1,
#  'laziness': 2,
#  'inventions.': 2,
#  'lighted': 2,
#  'worship': 2,
#  'god.': 11,
#  'sleeper': 2,
#  'snores.': 1,
#  'combing': 5,
#  "one's": 21,
#  'house': 26,
#  'or': 113,
#  'stories': 1,
#  'tall.': 2,
#  'bishop': 12,
#  'kills': 15,
#  'pawn.': 3,
#  'Total': 6,
#  'cholesterol': 1,
#  'considered': 16,
#  'heart.': 14,
#  'Open': 9,
#  'grow': 20,
#  'up.': 37,
#  'shopper': 11,
#  'demands': 10,
#  'refund': 1,
#  'store.': 25,
#  'operator': 7,
#  'tells': 7,
#  'it': 23,
#  'is.': 4,
#  'shadow': 9,
#  'keep': 47,
#  'off': 32,
#  'frog': 11,
#  'catches': 8,
#  'officer': 3,
#  'directs': 12,
#  'trafic.': 2,
#  'trapped': 1,
#  'hair': 28,
#  'express': 11,
#  'yourself.': 21,
#  'unlikely': 20,
#  'weapon': 16,
#  'committing': 1,
#  'crime.': 10,
#  'nonprofit': 2,
#  'actors.': 1,
#  'False': 65,
#  'cotton': 22,
#  'clothing,.': 1,
#  'Lateral': 2,
#  'neurons': 3,
#  'specialized': 4,
#  'projections': 1,
#  'called': 6,
#  'dendrites': 1,
#  'axons.': 1,
#  'structural': 6,
#  'cinema': 9,
#  'motion': 2,
#  'pictures.': 6,
#  'government': 15,
#  'disorder.': 3,
#  'past': 52,
#  'smoker': 4,
#  'cigarette.': 3,
#  'unregistered': 4,
#  'attorney': 3,
#  'case.': 4,
#  'Former': 45,
#  'guitar': 26,
#  'strings.': 6,
#  'Causal': 2,
#  'ocean': 12,
#  'trunk': 11,
#  'storage': 9,
#  'utensils.': 1,
#  'sudden': 4,
#  'tie.': 3,
#  'mechanic': 11,
#  'oils': 6,
#  'machine.': 5,
#  'inverted': 6,
#  'blackboard': 2,
#  'message': 4,
#  'it.': 39,
#  'astonished': 1,
#  'needles': 8,
#  'mercilessly.': 1,
#  'Wild': 9,
#  'grape': 2,
#  'generally': 25,
#  'green.': 8,
#  'wrong': 12,
#  'computer': 18,
#  'write': 21,
#  'emails.': 1,
#  'Ferrous': 1,
#  'salt': 14,
#  'key': 18,
#  'mountain': 7,
#  'divides': 10,
#  'continent.': 2,
#  'inland': 1,
#  'contract': 6,
#  'defining': 4,
#  'rights.': 1,
#  'dome-shaped': 1,
#  'ceiling': 9,
#  'cover.': 2,
#  'shelter': 5,
#  'offers': 16,
#  'free': 46,
#  'fried': 4,
#  'avocado': 2,
#  'skin.': 25,
#  'little': 62,
#  'fork': 25,
#  'vegetables.': 12,
#  'affordable': 4,
#  'community': 6,
#  'broken.': 2,
#  'squalid': 1,
#  'butter': 13,
#  'toast.': 4,
#  'Warm': 5,
#  'bacon': 2,
#  'pig.': 2,
#  'collapsible': 5,
#  'crutch': 7,
#  'gain': 4,
#  'sympathy.': 4,
#  'busy': 9,
#  'watching.': 5,
#  'solid': 11,
#  'earth': 9,
#  'very': 58,
#  'heavy.': 8,
#  'ultimate': 8,
#  'shirt': 14,
#  'atract': 1,
#  'online': 6,
#  'thinks.': 1,
#  'industrial': 5,
#  'fishing': 16,
#  'getting': 111,
#  'drunk.': 10,
#  'hand': 21,
#  'four': 16,
#  'fingers': 1,
#  'thumb.': 2,
#  'Closed': 1,
#  'stores': 24,
#  'sells': 8,
#  'their': 29,
#  'products.': 17,
#  'Unified': 1,
#  'police': 25,
#  'helps': 21,
#  'active': 22,
#  'broker': 3,
#  'trades': 3,
#  'client.': 3,
#  'different': 38,
#  'vegetables': 10,
#  ...}

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
wordcloud = WordCloud()
wordcloud.generate_from_frequencies(frequencies=word_freq_map)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# Here, we can see there are a lot of stop words, let's try to remove them

# %%
import nltk
from nltk.corpus import stopwords
 
nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Stopwords like "not" can cause an problem, let's see if we have them in our dataset.

# %%
for idx, row in df_train.iterrows():
    if " not " in row.to_dict()['sentence1']:
        print(row)
# Out:
# sentence1        Attention is drawn to something not ordinary.
# sentence2    Overt attention is drawn to something not ordi...
# modifier                                                 overt
# noun                                                 attention
# label                                                        2
# idx                                                      10050
# Name: 2552, dtype: object
# sentence1           You use a yard to park trucks not in use.
# sentence2    You use a marked yard to park trucks not in use.
# modifier                                               marked
# noun                                                     yard
# label                                                       2
# idx                                                      4474
# Name: 2904, dtype: object
# sentence1             Wind is felt but not seen.
# sentence2    Vertical wind is felt but not seen.
# modifier                                vertical
# noun                                        wind
# label                                          2
# idx                                        13163
# Name: 5810, dtype: object
# sentence1    Wallpaper is used for walls that are not painted.
# sentence2    Lightweight wallpaper is used for walls that a...
# modifier                                           lightweight
# noun                                                 wallpaper
# label                                                        2
# idx                                                       7514
# Name: 5900, dtype: object
# sentence1           Revenge is fitting if not destructive.
# sentence2    Future revenge is fitting if not destructive.
# modifier                                            future
# noun                                               revenge
# label                                                    2
# idx                                                  12005
# Name: 8705, dtype: object
# sentence1             The sun cooks anything not in the shade.
# sentence2    The fictional sun cooks anything not in the sh...
# modifier                                             fictional
# noun                                                       sun
# label                                                        0
# idx                                                       9138
# Name: 10415, dtype: object
# sentence1        Attention is drawn to something not ordinary.
# sentence2    Possible attention is drawn to something not o...
# modifier                                              possible
# noun                                                 attention
# label                                                        2
# idx                                                        208
# Name: 11883, dtype: object
# sentence1    Something that might happen as a consequence o...
# sentence2    Something that might happen as a consequence o...
# modifier                                                  fake
# noun                                                   talking
# label                                                        2
# idx                                                       3499
# Name: 11995, dtype: object
# sentence1           Revenge is fitting if not destructive.
# sentence2    Little revenge is fitting if not destructive.
# modifier                                            little
# noun                                               revenge
# label                                                    2
# idx                                                  15574
# Name: 12519, dtype: object
# sentence1    A closet is for supplies you do not use everyday.
# sentence2    A full closet is for supplies you do not use e...
# modifier                                                  full
# noun                                                    closet
# label                                                        2
# idx                                                       3870
# Name: 12801, dtype: object

# %% [markdown]
# Here, we can't remove every stopword as it can cause issues (change in context)
